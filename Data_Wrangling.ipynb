# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhrumi-Kansara/Data-Wrangling-on-diabetes-patient-dataset/blob/main/Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assessing Data
#
# Assessing Data is required:
#
# - To understand data more deeply before cleaning it
#
# - to clean data: find where mistakes(unclean data) are

# %% [markdown]
# unclean data
#
# 1. Dirty data(with quality issues)
#   - low quality data, has content issues
#
# 2. Messy Data(with tidiness issues)
#   - untidy data, has structural issues
#
#
# 1. Dirty data
#   - duplicate data
#   - missing data
#   - corrupt data
#   - inaccurate data
#
# 2. Messy data
#
# - properties of tidy data
#   - each variable has column
#   - each observation has row
#   - each observation unit forms a table

# %% [markdown]
# Goal
#
# - Assessing data:
#   - manually
#     - find quality issues
#   - programmatically

# %% [markdown]
# # understanding datasets
#
# 1. patients
#   - diabitites patients
# 2. treatments
#   - two methods to give insuline to patients
#   - patients divided into two groups
#   - [175 pre each group from patinets table]
#   - group 1: given medicine
#   - group 2: given injection
# 3. adverse reaction
#   - patients who have got adverse reaction through treatments given
#
#
# # outcome
#   - check if both treatments are effective in same manner

# %%
import pandas as pd
import numpy as np

# %%
patients=pd.read_csv('/content/patients.csv')

# %%
treatments=pd.read_csv('/content/treatments.csv')

# %%
adverse=pd.read_csv('/content/adverse_reactions.csv')

# %%
patients.shape
# Out:
# (503, 14)

# %%
treatments.shape
# Out:
# (280, 7)

# %%
adverse.shape
# Out:
# (34, 3)

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
patients['state'].unique()
#some state are in full form and some in abbrivation
# Out:
# array(['California', 'Illinois', 'Nebraska', 'NJ', 'AL', 'Florida', 'NV',
#        'CA', 'MO', 'New York', 'MI', 'TN', 'VA', 'OK', 'GA', 'MT', 'MA',
#        'NY', 'NM', 'IL', 'LA', 'PA', 'CO', 'ME', 'WI', 'SD', 'MN', 'FL',
#        'WY', 'OH', 'IA', 'NC', 'IN', 'CT', 'KY', 'DE', 'MD', 'AZ', 'TX',
#        'NE', 'AK', 'ND', 'KS', 'MS', 'WA', 'SC', 'WV', 'RI', 'NH', 'OR',
#        nan, 'VT', 'ID', 'DC', 'AR'], dtype=object)

# %%
treatments.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
treatments
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0             NaN
# 1            0.97
# ...

# %%
patients.info()
#missisng values in [address, city, state, zip_code, country, contact]
#assigned_sex,birth_date: convert datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients[patients['address'].isnull()]
#missing values for [address, city, state, zip_code, country, contact] (index: 209-269)
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
adverse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 944.0+ bytes

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
treatments.describe()
#hba1c_change: sharpe jump between 50% value and 75% value [change 9 instade of 4]
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
patients.sample(5)
#phone no stored in different forments
# Out:
#      patient_id assigned_sex  given_name     surname                  address  \
# 145         146         male       Sauli  Koivuniemi       1990 Spring Avenue
# 149         150         male  Wawrzyniec  Nowakowski   1525 Crestview Terrace
# 124         125         male        Ming         Hsu     2945 Ferguson Street
# 27           28         male      Joseph      Tucker         4982 Wood Street
# 279         280       female  Hanna-Mari     Filatov  2127 Columbia Mine Road
#
#               city state  zip_code        country  \
# 145     Eagleville    PA   19403.0  United States
# 149  Mountain Home    TX   78058.0  United States
# 124         Quincy    MA    2169.0  United States
# 27          Venice    LA   70091.0  United States
# 279       Riverton    WV   26814.0  United States
#
#                                           contact  birthdate  weight  height  \
# 145   SauliKoivuniemi@einrot.com+1 (267) 679-4137  7/24/1974   170.9      66
# ...

# %%
patients.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# Length: 503, dtype: bool

# %%
patients[patients['address'].duplicated()]
# Out:
#      patient_id assigned_sex given_name     surname             address  \
# 29           30         male       Jake    Jakobsen   648 Old Dear Lane
# 219         220         male         Mỹ       Quynh                 NaN
# 229         230         male       John         Doe     123 Main Street
# 230         231       female  Elisabeth     Knudsen                 NaN
# 234         235       female    Martina   Tománková                 NaN
# 237         238         male       John         Doe     123 Main Street
# 242         243         male       John     O'Brian                 NaN
# 244         245         male       John         Doe     123 Main Street
# 249         250         male   Benjamin      Mehler                 NaN
# 251         252         male       John         Doe     123 Main Street
# 257         258         male        Jin        Kung                 NaN
# 264         265       female   Wafiyyah      Asfour                 NaN
# ...

# %% [markdown]
# # Data Quality Dimensions
#
# [dividing data into different qualtity issues]
#
# 1. completeness issues - c
# 2. validity issues - v
# 3. accuracy issues - a
# 4. consistency issues - ic (inconsistance)
#
#
# manuall assessment
#
# -->Quality realated
# 1. patient
# 	- [v] zip code: in decimal [convert to string]
#   - [v] zip code: some zip code of 4 digit
# 	- [ic] state: some state are in full form and some in abbrivation
# 	- [c] missing values for [address, city, state, zip_code, country, contact] (index: 209-269)
# 	- [?] incorrect datatypes: assigned_sex: convert to categorical, birth_date: convert to date
# 	- [a] hight,weight: min is a lot smaller [describe()]
# 	- [c] contact: phone no stored in different forments
# 	- [ic] duplicate data: not useful data [are some placeholders]
#
# 2. treatment
# 	- [c] hba1c_change: missing values (hba1c_change=hba1c_start-hba1c_end)
# 	- [a] sharpe jump between 50% value and 75% value [change 9 instade of 4] (errorneous)
# 	- [v] novodra, auralin: u attached with numbers
# 	- [v] novodra, auralin: inconsistent data type: convert object to neumarical data
# 	- [ic] novodra, auralin: use '-' instead of NaN
# 	- [c] only 280 rows are there instade of 350
#   - [ic] name & surname: in lower case
#
# 3. adverse effect
# 	- [ic] name & surname: in lower case
#
# -->Tidiness realated
#
#
# 1. treatments
#    - auralin, novodera: 3 peice of info stored := convert it to 3 cols: lower_dose,upper_dose, treatement_type(auralin, novoders)
#
# 2. adverse effect
# 	- no need of seperate table(1 to 1 relation ship between adverse and patient):= add averse_effect col to

# %% [markdown]
# # Cleaning Data
#
# clean data in following provided order
# 1. Completeness issues
# 2. Tidiness issues
# 3. Remaning Data quality issues (Validity, accuracy and consistency)
#
# steps involved in data cleaning
# 1. define: how you would clean
# 2. code
# 3. test

# %% [markdown]
# create copies of DataFrame before cleaing data

# %%
patients_copy=patients.copy()
treatments_copy=treatments.copy()
adverse_copy=adverse.copy()

# %% [markdown]
# ## cleaning data with completeness issue

# %% [markdown]
# 1. missing values for [address, city, state, zip_code, country, contact] (index: 209-269)
# 2. only 280 rows are there instade of 350
# 3. hba1c_change: missing values (hba1c_change=hba1c_start-hba1c_end)

# %%
## 1. missing values for [address, city, state, zip_code, country, contact] (index: 209-269)

#checking null values
patients_copy[patients_copy['address'].isnull()]
#here col that are null are either categorical or string there isn't a way to guess those values -> leave them as it is
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
## 2. only 280 rows are there instade of 350

#define: concate treatments_cut dataframe with treatment dataframe
treatments_cut=pd.read_csv('/content/treatments_cut.csv')

# %%
treatments_cut.shape
# Out:
# (70, 7)

# %%
treatments.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
treatments_cut.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
#code: concating 
treatments = pd.concat([treatments, treatments_cut], ignore_index=True, sort=False)

# %%
treatments.shape
# Out:
# (350, 7)

# %%
## 3. hba1c_change: missing values (hba1c_change=hba1c_start-hba1c_end)

#define: (hba1c_change=hba1c_start-hba1c_end)

#code:
treatments['hba1c_change']=treatments['hba1c_start']-treatments['hba1c_end']

# %%
#test
treatments.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   350.000000  350.000000    350.000000
# mean      7.956343    7.560057      0.396286
# std       0.545328    0.545456      0.059283
# min       7.500000    7.010000      0.200000
# 25%       7.650000    7.270000      0.350000
# 50%       7.785000    7.400000      0.390000
# 75%       7.950000    7.557500      0.440000
# max       9.950000    9.580000      0.540000

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   auralin       350 non-null    object
#  3   novodra       350 non-null    object
#  4   hba1c_start   350 non-null    float64
#  5   hba1c_end     350 non-null    float64
#  6   hba1c_change  350 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 19.3+ KB

# %% [markdown]
# ## Cleaning Tidiness issues
#
#
#
# 1. treatments
#    - auralin, novodera: 3 peice of info stored := convert it to 3 cols: lower_dose,upper_dose, treatement_type(auralin, novoders)
#
# 2. adverse effect
# 	- no need of seperate table(1 to 1 relation ship between adverse and patient):= add averse_effect col to

# %% [markdown]
# ### 1. treatments: auralin, novodera: 3 peice of info stored := convert it to 3 cols: lower_dose,upper_dose, treatement_type(auralin, novoders)

# %%
#define: a. convert it to 2 cols: dose,treatment_type(auralin, novoders) := solving using melt()

#code:
treatments=pd.melt(treatments, id_vars=['given_name','surname','hba1c_start','hba1c_end','hba1c_change'],var_name='treatment', value_name='dose')

#  id_vars: pass cols in which no change is requred
#  varname: combines remaning col into single col with column name as value
#  value_name: stores value of col

# %%
treatments.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0   veronika    jindrová         7.63       7.20          0.43   auralin
# 1     elliot  richardson         7.56       7.09          0.47   auralin
# 2   yukitaka    takenaka         7.68       7.25          0.43   auralin
# 3       skye  gormanston         7.97       7.62          0.35   auralin
# 4     alissa      montez         7.78       7.46          0.32   auralin
#
#         dose
# 0  41u - 48u
# 1          -
# 2          -
# 3  33u - 36u
# 4          -

# %%
#  patient where auaralin dose is '-' means -> novoders was given to them and vice versa

#  remove those
treatments=treatments[treatments['dose']!='-']

# %%
# define: b. seperate dose into lower dose, upper dose
treatments['start_dose'],treatments['end_dose']=treatments['dose'].str.split('-').str
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.

# %%
treatments.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0   veronika    jindrová         7.63       7.20          0.43   auralin
# 3       skye  gormanston         7.97       7.62          0.35   auralin
# 6     sophia      haugen         7.65       7.27          0.38   auralin
# 7      eddie      archer         7.89       7.55          0.34   auralin
# 9       asia     woźniak         7.76       7.37          0.39   auralin
#
#         dose start_dose end_dose
# 0  41u - 48u       41u       48u
# 3  33u - 36u       33u       36u
# 6  37u - 42u       37u       42u
# 7  31u - 38u       31u       38u
# 9  30u - 36u       30u       36u

# %%
# remove redundent dose column
treatments.drop(columns={'dose'}, inplace=True)

# %%
treatments
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0       veronika    jindrová         7.63       7.20          0.43   auralin
# 3           skye  gormanston         7.97       7.62          0.35   auralin
# 6         sophia      haugen         7.65       7.27          0.38   auralin
# 7          eddie      archer         7.89       7.55          0.34   auralin
# 9           asia     woźniak         7.76       7.37          0.39   auralin
# ..           ...         ...          ...        ...           ...       ...
# 688  christopher    woodward         7.51       7.06          0.45   novodra
# 690        maret    sultygov         7.67       7.30          0.37   novodra
# 694        lixue       hsueh         9.21       8.80          0.41   novodra
# 696        jakob    jakobsen         7.96       7.51          0.45   novodra
# 698        berta  napolitani         7.68       7.21          0.47   novodra
#
#     start_dose end_dose
# ...

# %%
#reseting index
treatments.reset_index(drop=True, inplace=True)

# %%
treatments
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0       veronika    jindrová         7.63       7.20          0.43   auralin
# 1           skye  gormanston         7.97       7.62          0.35   auralin
# 2         sophia      haugen         7.65       7.27          0.38   auralin
# 3          eddie      archer         7.89       7.55          0.34   auralin
# 4           asia     woźniak         7.76       7.37          0.39   auralin
# ..           ...         ...          ...        ...           ...       ...
# 345  christopher    woodward         7.51       7.06          0.45   novodra
# 346        maret    sultygov         7.67       7.30          0.37   novodra
# 347        lixue       hsueh         9.21       8.80          0.41   novodra
# 348        jakob    jakobsen         7.96       7.51          0.45   novodra
# 349        berta  napolitani         7.68       7.21          0.47   novodra
#
#     start_dose end_dose
# ...

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  350 non-null    float64
#  5   treatment     350 non-null    object
#  6   start_dose    350 non-null    object
#  7   end_dose      350 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 22.0+ KB

# %% [markdown]
# ### 2. adverse effect: no need of seperate table

# %%
#capitalizing 
adverse['given_name']=adverse['given_name'].str.capitalize()
adverse['surname']=adverse['surname'].str.capitalize()

# %%
#merging 
patients=patients.merge(adverse, how='left', left_on=['given_name','surname'], right_on = ['given_name','surname'])

# %%
patients.shape
# Out:
# (503, 15)

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503 entries, 0 to 502
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   patient_id        503 non-null    int64
#  1   assigned_sex      503 non-null    object
#  2   given_name        503 non-null    object
#  3   surname           503 non-null    object
#  4   address           491 non-null    object
#  5   city              491 non-null    object
#  6   state             491 non-null    object
#  7   zip_code          491 non-null    float64
#  8   country           491 non-null    object
#  9   contact           491 non-null    object
#  10  birthdate         503 non-null    object
#  11  weight            503 non-null    float64
#  12  height            503 non-null    int64
#  13  bmi               503 non-null    float64
#  14  adverse_reaction  32 non-null     object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 62.9+ KB

# %% [markdown]
# ## 3. Remaning Data quality issues (Validity, accuracy and consistency)

# %% [markdown]
# ### Validity
#
# 1. patient
# 	- zip code: in decimal [convert to string] and some zip code of 4 digit
# 2. treatment
# 	- novodra, auralin: u attached with numbers
# 	- novodra, auralin: inconsistent data type: convert object to neumarical data

# %%
## 1. patient:  zip code: in decimal [convert to string]   

## removing null zipcodes
patients=patients[patients['zip_code'].isnull()==False]

# %%
#zip code: in decimal [float to int]   
patients['zip_code']=patients['zip_code'].astype(int)

# %%
# int to string
patients['zip_code']=patients['zip_code'].astype(str)

# %%
# convert xip to 5 length
patients['zip_code']=patients['zip_code'].str.zfill(5)

# %%
## 2. treatment:   novodra, auralin: u attached with numbers 
treatments['start_dose']=treatments['start_dose'].str.replace('u','')
treatments['end_dose']=treatments['end_dose'].str.replace('u','')
treatments.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0   veronika    jindrová         7.63       7.20          0.43   auralin
# 1       skye  gormanston         7.97       7.62          0.35   auralin
# 2     sophia      haugen         7.65       7.27          0.38   auralin
# 3      eddie      archer         7.89       7.55          0.34   auralin
# 4       asia     woźniak         7.76       7.37          0.39   auralin
#
#   start_dose end_dose
# 0        41        48
# 1        33        36
# 2        37        42
# 3        31        38
# 4        30        36

# %%
## 2. treatment novodra, auralin: inconsistent data type: convert object to neumarical data

#checking type
print(type(treatments['end_dose'][0]),type(treatments['start_dose'][0]))
# Out:
# <class 'str'> <class 'str'>

# %%
#converting to int
treatments['start_dose']=treatments['start_dose'].astype(int)
treatments['end_dose']=treatments['end_dose'].astype(int)

# %%
treatments.head()
# Out:
#   given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0   veronika    jindrová         7.63       7.20          0.43   auralin
# 1       skye  gormanston         7.97       7.62          0.35   auralin
# 2     sophia      haugen         7.65       7.27          0.38   auralin
# 3      eddie      archer         7.89       7.55          0.34   auralin
# 4       asia     woźniak         7.76       7.37          0.39   auralin
#
#    start_dose  end_dose
# 0          41        48
# 1          33        36
# 2          37        42
# 3          31        38
# 4          30        36

# %% [markdown]
# # Consistency
#
# 1. patient
# 	- state: some state are in full form and some in abbrivation
# 	- incorrect datatypes: assigned_sex: convert to categorical, birth_date: convert to date
# 	- duplicate data: not useful data [are some placeholders]
#
# 2. treatment
# 	- novodra, auralin: use '-' instead of NaN
#   - name & surname: in lower case
#
# 3. adverse effect
# 	- name & surname: in lower case

# %% [markdown]
# ## 1. patient:

# %%
##1. state: some state are in full form and some in abbrivation
patients['state'].unique()
# Out:
# array(['California', 'Illinois', 'Nebraska', 'NJ', 'AL', 'Florida', 'NV',
#        'CA', 'MO', 'New York', 'MI', 'TN', 'VA', 'OK', 'GA', 'MT', 'MA',
#        'NY', 'NM', 'IL', 'LA', 'PA', 'CO', 'ME', 'WI', 'SD', 'MN', 'FL',
#        'WY', 'OH', 'IA', 'NC', 'IN', 'CT', 'KY', 'DE', 'MD', 'AZ', 'TX',
#        'NE', 'AK', 'ND', 'KS', 'MS', 'WA', 'SC', 'WV', 'RI', 'NH', 'OR',
#        'VT', 'ID', 'DC', 'AR'], dtype=object)

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
patients['state']=patients['state'].apply(lambda x:  us_state_to_abbrev.get(x) if us_state_to_abbrev.get(x) else x)

# %%
patients['state'].unique()
# Out:
# array(['CA', 'IL', 'NE', 'NJ', 'AL', 'FL', 'NV', 'MO', 'NY', 'MI', 'TN',
#        'VA', 'OK', 'GA', 'MT', 'MA', 'NM', 'LA', 'PA', 'CO', 'ME', 'WI',
#        'SD', 'MN', 'WY', 'OH', 'IA', 'NC', 'IN', 'CT', 'KY', 'DE', 'MD',
#        'AZ', 'TX', 'AK', 'ND', 'KS', 'MS', 'WA', 'SC', 'WV', 'RI', 'NH',
#        'OR', 'VT', 'ID', 'DC', 'AR'], dtype=object)

# %%
## incorrect datatypes: assigned_sex, birthdate 
# 1. assigned_sex: convert to categorical
patients['assigned_sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
patients['assigned_sex']=pd.Categorical(patients['assigned_sex'])

# %%
patients['assigned_sex']
# Out:
# 0      female
# 1      female
# 2        male
# 3        male
# 4        male
#         ...
# 498      male
# 499      male
# 500    female
# 501    female
# 502      male
# Name: assigned_sex, Length: 491, dtype: category
# Categories (2, object): ['female', 'male']

# %%
# 2. birthdate: convert to date
type(patients['birthdate'][0])
# Out:
# str

# %%
patients['birthdate']=pd.to_datetime(patients['birthdate'])

# %% [markdown]
# ## treatment

# %%
## 1.novodra, auralin: use '-' instead of NaN
treatments
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change treatment  \
# 0       veronika    jindrová         7.63       7.20          0.43   auralin
# 1           skye  gormanston         7.97       7.62          0.35   auralin
# 2         sophia      haugen         7.65       7.27          0.38   auralin
# 3          eddie      archer         7.89       7.55          0.34   auralin
# 4           asia     woźniak         7.76       7.37          0.39   auralin
# ..           ...         ...          ...        ...           ...       ...
# 345  christopher    woodward         7.51       7.06          0.45   novodra
# 346        maret    sultygov         7.67       7.30          0.37   novodra
# 347        lixue       hsueh         9.21       8.80          0.41   novodra
# 348        jakob    jakobsen         7.96       7.51          0.45   novodra
# 349        berta  napolitani         7.68       7.21          0.47   novodra
#
#      start_dose  end_dose
# ...

# %%
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city state zip_code  \
# 0         576 Brown Bear Drive  Rancho California    CA    92390
# 1    2370 University Hill Road          Armstrong    IL    61812
# 2        1493 Poling Farm Road               York    NE    68467
# ...
